# %%
def hello():
    print('hello')

# %%
def hello(x,y=10):
    z = x + y
    print(z)

# %%
def hello(name, age):
    msg = f'{name} is {age} years old'
    print(msg)

# %%
def a(x, y):
    result = x + y*2
    return result
b = a(1,2)
c = a(2,3)
print(a(b,c))
# Out:
# 21

# %%
def a(x):
    result = 0
    while result < 10:
      result = result + x
      if result==5:
        return result
    return result
b = a(1)
c = a(2)
print(b)
print(c)
# Out:
# 5
# 10

# %%
def tf(value):
  return 2 * value - 1
test_values = [0.0, 0.011, 0.25, 0.5, 0.54, 0.75, 1.0]
scaled_values = [tf(value) for value in test_values]
print("Original values:", test_values)
print("Scaled values:", scaled_values)
# Out:
# Original values: [0.0, 0.011, 0.25, 0.5, 0.54, 0.75, 1.0]
# Scaled values: [-1.0, -0.978, -0.5, 0.0, 0.08000000000000007, 0.5, 1.0]

# %%
def a(n):
    if n == 0 or n == 1:
        return 1
    else:
        return n + a(n-1)
print(a(10))
# Out:
# 55

# %%
with open('test.txt','w') as f1:
    f1.write('good night')

# %%
import datetime
print(datetime.datetime.now())
print(datetime.date.today())
# Out:
# 2024-09-26 08:58:21.462055
# 2024-09-26

# %%
import datetime as dd
print(dd.datetime.now())
print(dd.date.today())
# Out:
# 2024-09-26 08:59:29.909108
# 2024-09-26

# %%
import numpy as np
import pandas as pd

# %%
s=pd.Series([1,3,5,np.nan,6,8])
s
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %%
dates = pd.date_range("20130101", periods=6)
dates
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df = pd.DataFrame(np.random.randn(6,4), index=dates,
columns=list("ABCD"))
df
# Out:
#                    A         B         C         D
# 2013-01-01 -0.734132 -2.257484 -0.271681 -1.344982
# 2013-01-02  1.113120 -0.965871 -1.208439 -1.121982
# 2013-01-03 -0.102159  0.817471 -0.930393  1.034841
# 2013-01-04 -0.940691 -1.821800  0.634088 -0.839239
# 2013-01-05  0.961579 -1.515758  2.087630 -1.140537
# 2013-01-06  0.779339  0.363228  1.777582  0.146701

# %%
dates = pd.date_range("20130101", periods=6)
print(dates)
df = pd.DataFrame(np.random.randn(6,4), index=dates,
columns=list("ABCD"))
df
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')
#                    A         B         C         D
# 2013-01-01 -1.533846 -0.592804 -1.646111  0.432988
# 2013-01-02 -0.427074  0.013964 -0.334330 -0.896445
# 2013-01-03  3.134039 -0.067493 -0.585382 -0.501542
# 2013-01-04 -0.519841  1.533535  0.434838 -0.644807
# 2013-01-05  1.564409 -1.256852  1.683095  2.222271
# 2013-01-06  1.487069  0.844456 -0.200531 -0.159322

# %%
print(df.head())
print(df.tail(3))
print(df.index)
df.columns
# Out:
#                    A         B         C         D
# 2013-01-01 -1.533846 -0.592804 -1.646111  0.432988
# 2013-01-02 -0.427074  0.013964 -0.334330 -0.896445
# 2013-01-03  3.134039 -0.067493 -0.585382 -0.501542
# 2013-01-04 -0.519841  1.533535  0.434838 -0.644807
# 2013-01-05  1.564409 -1.256852  1.683095  2.222271
#                    A         B         C         D
# 2013-01-04 -0.519841  1.533535  0.434838 -0.644807
# 2013-01-05  1.564409 -1.256852  1.683095  2.222271
# 2013-01-06  1.487069  0.844456 -0.200531 -0.159322
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')
# Index(['A', 'B', 'C', 'D'], dtype='object')

# %%
df2 = df.copy()
df2.to_numpy()
# Out:
# array([[-1.53384618, -0.59280443, -1.64611142,  0.43298768],
#        [-0.42707363,  0.01396403, -0.3343303 , -0.89644531],
#        [ 3.13403884, -0.06749333, -0.58538215, -0.50154172],
#        [-0.51984134,  1.53353472,  0.43483815, -0.64480706],
#        [ 1.56440862, -1.25685231,  1.68309519,  2.22227099],
#        [ 1.48706873,  0.84445631, -0.20053129, -0.15932181]])

# %%
a = df.describe()
print(a)
# Out:
#               A         B         C         D
# count  6.000000  6.000000  6.000000  6.000000
# mean   0.617459  0.079134 -0.108070  0.075524
# std    1.731977  0.996304  1.109609  1.147873
# min   -1.533846 -1.256852 -1.646111 -0.896445
# 25%   -0.496649 -0.461477 -0.522619 -0.608991
# 50%    0.529998 -0.026765 -0.267431 -0.330432
# 75%    1.545074  0.636833  0.275996  0.284910
# max    3.134039  1.533535  1.683095  2.222271

# %%
df2 = df
df.T
#橫豎對調
# Out:
#    2013-01-01  2013-01-02  2013-01-03  2013-01-04  2013-01-05  2013-01-06
# A   -1.533846   -0.427074    3.134039   -0.519841    1.564409    1.487069
# B   -0.592804    0.013964   -0.067493    1.533535   -1.256852    0.844456
# C   -1.646111   -0.334330   -0.585382    0.434838    1.683095   -0.200531
# D    0.432988   -0.896445   -0.501542   -0.644807    2.222271   -0.159322

# %%
df.sort_index(axis=1, ascending=True)
# Out:
#                    A         B         C         D
# 2013-01-01 -1.533846 -0.592804 -1.646111  0.432988
# 2013-01-02 -0.427074  0.013964 -0.334330 -0.896445
# 2013-01-03  3.134039 -0.067493 -0.585382 -0.501542
# 2013-01-04 -0.519841  1.533535  0.434838 -0.644807
# 2013-01-05  1.564409 -1.256852  1.683095  2.222271
# 2013-01-06  1.487069  0.844456 -0.200531 -0.159322

# %%
print(df["A"])
df[0:3]
df["A"][0:3]
# Out:
# 2013-01-01   -1.533846
# 2013-01-02   -0.427074
# 2013-01-03    3.134039
# 2013-01-04   -0.519841
# 2013-01-05    1.564409
# 2013-01-06    1.487069
# Freq: D, Name: A, dtype: float64
# 2013-01-01   -1.533846
# 2013-01-02   -0.427074
# 2013-01-03    3.134039
# Freq: D, Name: A, dtype: float64

# %%
print(df.loc[dates[0]])
print(df.loc[:, ["A","B"]])
print(df.loc["20130102":"20130104", ["A","B"]])
df.loc[dates[0],"A"]
# Out:
# A   -1.533846
# B   -0.592804
# C   -1.646111
# D    0.432988
# Name: 2013-01-01 00:00:00, dtype: float64
#                    A         B
# 2013-01-01 -1.533846 -0.592804
# 2013-01-02 -0.427074  0.013964
# 2013-01-03  3.134039 -0.067493
# 2013-01-04 -0.519841  1.533535
# 2013-01-05  1.564409 -1.256852
# 2013-01-06  1.487069  0.844456
#                    A         B
# 2013-01-02 -0.427074  0.013964
# 2013-01-03  3.134039 -0.067493
# 2013-01-04 -0.519841  1.533535
# -1.5338461755427109

# %%
print(df.iloc[3])
print(df.iloc[3:5, 0:2])
df.iloc[1:3, :]
# Out:
# A   -0.519841
# B    1.533535
# C    0.434838
# D   -0.644807
# Name: 2013-01-04 00:00:00, dtype: float64
#                    A         B
# 2013-01-04 -0.519841  1.533535
# 2013-01-05  1.564409 -1.256852
#                    A         B         C         D
# 2013-01-02 -0.427074  0.013964 -0.334330 -0.896445
# 2013-01-03  3.134039 -0.067493 -0.585382 -0.501542

# %%
print(df[df>0])
df[df["A"]>0]
# Out:
#                    A         B         C         D
# 2013-01-01       NaN       NaN       NaN  0.432988
# 2013-01-02       NaN  0.013964       NaN       NaN
# 2013-01-03  3.134039       NaN       NaN       NaN
# 2013-01-04       NaN  1.533535  0.434838       NaN
# 2013-01-05  1.564409       NaN  1.683095  2.222271
# 2013-01-06  1.487069  0.844456       NaN       NaN
#                    A         B         C         D
# 2013-01-03  3.134039 -0.067493 -0.585382 -0.501542
# 2013-01-05  1.564409 -1.256852  1.683095  2.222271
# 2013-01-06  1.487069  0.844456 -0.200531 -0.159322

# %%
df2 = df.copy()
df2["E"] = ["one", "one", "two", "three", "four", "three"]
df2[df2["E"].isin(["two", "four"])]
# Out:
#                    A         B         C         D     E
# 2013-01-03  3.134039 -0.067493 -0.585382 -0.501542   two
# 2013-01-05  1.564409 -1.256852  1.683095  2.222271  four

# %%
df2 = df.copy()
df2[df2>0] = -df2
df2
# Out:
#                    A         B         C         D
# 2013-01-01 -1.533846 -0.592804 -1.646111 -0.432988
# 2013-01-02 -0.427074 -0.013964 -0.334330 -0.896445
# 2013-01-03 -3.134039 -0.067493 -0.585382 -0.501542
# 2013-01-04 -0.519841 -1.533535 -0.434838 -0.644807
# 2013-01-05 -1.564409 -1.256852 -1.683095 -2.222271
# 2013-01-06 -1.487069 -0.844456 -0.200531 -0.159322

# %%
df1 = df.reindex(index=dates[0:4], columns=list(df.columns)+["E"])
df1.loc[dates[0]:dates[1],"E"]=1
df1
# Out:
#                    A         B         C         D    E
# 2013-01-01 -1.533846 -0.592804 -1.646111  0.432988  1.0
# 2013-01-02 -0.427074  0.013964 -0.334330 -0.896445  1.0
# 2013-01-03  3.134039 -0.067493 -0.585382 -0.501542  NaN
# 2013-01-04 -0.519841  1.533535  0.434838 -0.644807  NaN

# %%
df1.dropna()
# Out:
#                    A         B         C         D    E
# 2013-01-01 -1.533846 -0.592804 -1.646111  0.432988  1.0
# 2013-01-02 -0.427074  0.013964 -0.334330 -0.896445  1.0
